# %%
from solver import classic_solver
from aspen import aspen_solver
import partion
import numpy as np
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def model(u):
    return np.array([u**2+1, 2*max(u, 0)])

class Diffusion():
    def __init__(self, Nx, Amp=0, Period=0, Scale=1, model=None):
        self.val = np.zeros((Nx+1, 1))
        for i in range(Nx+1):
            self.val[i] = (
                Amp * np.sin(Period * 2*np.pi * (i+1) / (Nx+1)) + 1) * Scale
        self.model = model

# %%
# inital condition

x0 = 1/ (1+ np.exp(-0.05*(np.arange(200)-150)) )
x0 = np.reshape(x0, (-1, 1))
plt.plot(x0)

# %%
Nx = 200
Nt = 20
param = {
    'Nx': Nx, 
    'Nt': Nt,
}
D = Diffusion(Nx, 0.9, 1, 0.5e-1, model=model)
solver_cl = classic_solver(param, D)
solver_cl.setBoundary(0, 1)
solver_cl.x0 = np.copy(x0)
#solver_cl.setInitial(0.5, 2, 1)
solver_cl.setSources([0.6], [0])

X_cl, code, message = solver_cl.solve()
print(X_cl, message)
# Out:
# [[5.52778637e-04 1.82689946e-04 1.83817313e-04 ... 1.17251266e-03
#   1.20490224e-03 0.00000000e+00]
#  [5.81103734e-04 3.09400765e-04 3.62819458e-04 ... 2.31930027e-03
#   2.38818442e-03 0.00000000e+00]
#  [6.10879359e-04 4.30328142e-04 5.37684051e-04 ... 3.43713518e-03
#   3.54148642e-03 0.00000000e+00]
#  ...
#  [9.12934228e-01 9.70952878e-01 9.83122424e-01 ... 9.93845738e-01
#   9.93947340e-01 0.00000000e+00]
#  [9.16827304e-01 9.78328019e-01 9.88724206e-01 ... 9.95959150e-01
#   9.96024298e-01 0.00000000e+00]
#  [9.20561451e-01 9.85758237e-01 9.94188172e-01 ... 9.98007656e-01
#   9.98037480e-01 0.00000000e+00]] OK

# %%
Nx = 200
Nt = 20
Nd = 4
param = {
    'Nx': Nx, 
    'Nt': Nt,
    'Nd': Nd
}
D = Diffusion(Nx, 0.9, 1, 0.5e-1, model=model)

part = partion.partion_equally
solver_as = aspen_solver(param, D, part)
solver_as.setBoundary(0, 1)
solver_as.x0 = np.copy(x0)
#solver_as.setInitial(0.5, 2, 1)
solver_as.setSources([0.6], [0])
X, code, message = solver_as.solve()
print(X, message)
# Out:
# [[5.52778637e-04 1.78068762e-04 1.81002481e-04 ... 1.17045354e-03
#   1.20787379e-03 0.00000000e+00]
#  [5.81103734e-04 3.05232197e-04 3.60072715e-04 ... 2.31719383e-03
#   2.39062407e-03 0.00000000e+00]
#  [6.10879359e-04 4.26562036e-04 5.35016752e-04 ... 3.43498367e-03
#   3.54344986e-03 0.00000000e+00]
#  ...
#  [9.12934228e-01 9.76317755e-01 9.84041464e-01 ... 9.93854485e-01
#   9.93959163e-01 0.00000000e+00]
#  [9.16827304e-01 9.84215627e-01 9.89515661e-01 ... 9.95966686e-01
#   9.96035347e-01 0.00000000e+00]
#  [9.20561451e-01 9.92218174e-01 9.94836055e-01 ... 9.98014016e-01
#   9.98047800e-01 0.00000000e+00]] OK

# %%
step = 1
plt.style.use('dark_background')
plt.plot(X_cl[:, step], color = 'r')
plt.show()
plt.plot(X[:, step])
plt.show()
print(message)
# Out:
# OK

# %%
print('aspen/newton comparsion')
print('---global versus newton---')
print('gb_resbld = {}, resbld ={}'.format(solver_as.timelog.gb_resbld, solver_cl.timelog.resbld))
print('gb_jacbld = {}, jacbld = {}'.format(solver_as.timelog.gb_jacbld, solver_cl.timelog.jacbld))
print('gb_linsol = {}, linsol = {}'.format(solver_as.timelog.gb_linsol, solver_cl.timelog.linsol))
print('---local+global time vs newton time---')
t1 = solver_as.timelog.gb_resbld+solver_as.timelog.gb_jacbld \
      +solver_as.timelog.gb_linsol+np.sum(solver_as.timelog.lc_resbld) \
      +np.sum(solver_as.timelog.lc_jacbld)+np.sum(solver_as.timelog.lc_linsol)
t2 = solver_cl.timelog.resbld+solver_cl.timelog.jacbld \
      +solver_cl.timelog.linsol
print('aspen = {}, newton = {}'.format(t1, t2))
# Out:
# aspen/newton comparsion
# ---global versus newton---
# gb_resbld = 0.1190030574798584, resbld =0.2323141098022461
# gb_jacbld = 0.10679745674133301, jacbld = 0.361238956451416
# gb_linsol = 0.009038448333740234, linsol = 0.019852161407470703
# ---local+global time vs newton time---
# aspen = 0.5628783702850342, newton = 0.6134052276611328

# %%
plt.title('aspen iters vs newton iters')
plt.plot(solver_cl.timelog.kn, color = 'r', label='newton')
plt.plot(solver_as.timelog.aspen_iters, color = 'b', label='aspen')
plt.legend()
plt.show()

# %%
plt.title('subdomains iterations')

for i in range(Nd):
    plt.plot(solver_as.timelog.domain_iters[:, i], label='domain: {}'.format(i))
    
plt.legend()
plt.show()

plt.title('step2')
plt.xlabel('num of domain')
plt.ylabel('iterations')
plt.bar(np.arange(0, Nd, 1, dtype='int'), solver_as.timelog.domain_iters[2, :])
plt.show()

# %%
print('subdomain time')
print('---resbld---')
print(solver_as.timelog.lc_resbld)
print('---jacbld---')
print(solver_as.timelog.lc_jacbld)
print('---linsol---')
print(solver_as.timelog.lc_linsol)
# Out:
# subdomain time
# ---resbld---
# [0.06081533 0.03125191 0.02871156 0.02667999]
# ---jacbld---
# [0.08739066 0.03108668 0.02864981 0.02609062]
# ---linsol---
# [0.00381303 0.00120497 0.00116134 0.00118351]
