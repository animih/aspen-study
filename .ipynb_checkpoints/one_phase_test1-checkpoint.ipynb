# %%
# importing moudles
# and using some magic to autoreload them if changed
# %load_ext autoreload
# %autoreload 2

import sys

sys.path.append('./nonlin')
sys.path.append('./partion')
sys.path.append('./Probs')

from aspen import aspen
from newton import newton

import partion as pt
import wrapper as wp

from one_phase import one_phase
from fix_bd_1D import fxbd_1D
import numpy as np
import matplotlib.pyplot as plt

test = wp.test_decorator(wp.test)
plt.style.use('default')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# model to be studied
def model(u):
    return np.array([u**2+1, 2*max(u, 0)])

# %%
class Diffusion():
    def __init__(self, Nx, Amp=0, Period=0, Scale=1, model=None):
        self.val = np.zeros((Nx+1, 1))
        for i in range(Nx+1):
            self.val[i] = (
                Amp * np.sin(Period * 2*np.pi * (i+1) / (Nx+1)) + 1) * Scale
        self.model = model

# %% [markdown]
# Для начала возьмем $\tau / h^2$ = $ 250000 $

# %%
Nx = 5000
Nt = 10
param ={'Nx': Nx, 'Nt' : Nt}
x = np.linspace(0, 1, Nx)
D = Diffusion(Nx, 0.9, 1, 0.4e-2, model=model)
x0 = 2*np.exp(-x)*np.sin(3*np.pi/2*x)**2
x0 = x0.reshape(-1, 1)
bd1 = x0[0]
bd2 = x0[-1]

plt.plot(x, x0)
plt.show()

# %%
prob = one_phase(D, param)
solver_n = fxbd_1D(param, prob)
solver_n.setBoundary(bd1, bd2)
solver_n.setSources([0.7], [-0.8])

# %%
nl_solver = newton(crit_abs=1e-8)
solver_n.setSolver(nl_solver)

# %%
solver_n.setInitial(x0)
X, mes, t, delta = test(solver_n, sample_size = 4)
# Out:
# test started
# verdict : OK
# time : 56.42 +- 0.9869
# mean newton iterations:  4.4

# %%
wp.show_res(solver_n)
plt.show()

# %%
prob = one_phase(D, param)
solver = fxbd_1D(param, prob)
solver.setBoundary(bd1, bd2)
solver.setSources([0.7], [-0.8])
solver.setInitial(x0)

# %%
Nd = 5
partion = pt.partion_equally(Nx, Nd)
nl_solver = aspen(Nd, partion, crit_abs=1e-8)
solver.setSolver(nl_solver)

# %%
X, mes, t, delta = test(solver, sample_size=4)
# Out:
# test started
# verdict : OK
# time : 95.25 +- 1.117
# mean aspen iterations:  4.1

# %%
wp.show_res(solver, save='Diff0_ASPEN')
wp.bar_loc(solver, Nd, save='Diff0_mean_loc')

# %%
wp.compare([solver_n, solver], ['newton', 'aspen'], save='comp')
wp.bar_loc_step(solver, Nd, 0, save='step=0')
wp.bar_loc_step(solver, Nd, 5, save='step=5')
# Out:
# --time comparision--
# newton : 56.87653398513794
# aspen : 97.08794689178467

# %% [markdown]
# #### Исследуем зависимость от шага по времени

# %%
time = np.zeros((10, 2))
delta = np.zeros((10, 2))

Nx = 1000
Nd = 5

x = np.linspace(0, 1, Nx)
D = Diffusion(Nx, 0.9, 1, 0.2e-1, model=model)
x0 = np.exp(-x)*np.cos(3*np.pi/2*x)**2
x0 = x0.reshape(-1, 1)

nl_new = newton(crit_abs = 1e-6)
partion = pt.partion_equally(Nx, Nd)
nl_asp = aspen(Nd, partion, crit_abs=1e-6) 

for i in range(10):
    Nt = 4*(1+i)
    param ={'Nx': Nx, 'Nt' : Nt}
    prob = one_phase(D, param)
    solver = fxbd_1D(param, prob)
    solver.setBoundary(bd1, bd2)
    solver.setSources([0.7], [-0.8])
    solver.setInitial(x0)
    
    solver.setSolver(nl_new)
    _, mes, time[i, 0], delta[i, 0] = test(solver, sample_size=4)
    if(mes != 'OK'):
        print(mes, i) 
        
    prob = one_phase(D, param)
    solver = fxbd_1D(param, prob)
    solver.setBoundary(bd1, bd2)
    solver.setSources([0.7], [-0.8])
    solver.setInitial(x0)
    solver.setSolver(nl_asp)
    _, mes, time[i, 1], delta[i, 1] = test(solver, sample_size=4)
    if(mes != 'OK'):
        print(mes, i)
# Out:
# test started
# verdict : OK
# time : 1.713 +- 0.4177
# mean newton iterations:  4.5
# test started
# verdict : OK
# time : 4.512 +- 0.5645
# mean aspen iterations:  4.75
# test started
# verdict : OK
# time : 2.799 +- 0.5208
# mean newton iterations:  3.625
# test started
# verdict : OK
# time : 9.295 +- 0.6259
# mean aspen iterations:  3.875
# test started
# verdict : OK
# time : 4.701 +- 0.319
# mean newton iterations:  3.3333333333333335
# test started
# verdict : OK
# time : 10.84 +- 0.8829
# mean aspen iterations:  3.75
# test started
# verdict : OK
# time : 5.07 +- 0.3718
# mean newton iterations:  3.1875
# test started
# verdict : OK
# time : 13.11 +- 0.7712
# mean aspen iterations:  3.5625
# test started
# verdict : OK
# time : 5.875 +- 0.3631
# mean newton iterations:  3.15
# test started
# verdict : OK
# time : 15.09 +- 0.6357
# mean aspen iterations:  3.45
# test started
# verdict : OK
# time : 7.061 +- 0.4944
# mean newton iterations:  2.9583333333333335
# test started
# verdict : OK
# time : 17.31 +- 1.089
# mean aspen iterations:  3.0416666666666665
# test started
# verdict : OK
# time : 7.616 +- 0.1689
# mean newton iterations:  2.7857142857142856
# test started
# verdict : OK
# time : 18.85 +- 0.3529
# mean aspen iterations:  2.892857142857143
# test started
# verdict : OK
# time : 8.147 +- 0.1966
# mean newton iterations:  2.65625
# test started
# verdict : OK
# time : 21.29 +- 0.4794
# mean aspen iterations:  2.90625
# test started
# verdict : OK
# time : 8.874 +- 0.3192
# mean newton iterations:  2.5555555555555554
# test started
# verdict : OK
# time : 24.24 +- 0.9123
# mean aspen iterations:  2.888888888888889
# test started
# verdict : OK
# time : 10.6 +- 0.7363
# mean newton iterations:  2.45
# test started
# verdict : OK
# time : 28.58 +- 0.4417
# mean aspen iterations:  2.875

# %%
dif = 1 - time[:, 1]/time[:, 0]
dt = 1/(4*np.arange(1, 11))

plt.title('Aspen vs Newton')
plt.xlabel('$dt$')
plt.ylabel('diff in time, $(t_{new}-t) /t_{new}$')
plt.plot(dt, dif)
plt.fill_between(dt, dif+np.sqrt(delta[:, 0]**2+delta[:, 1]**2)/time[:, 0],
                dif-np.sqrt(delta[:, 0]**2+delta[:, 1]**2)/time[:, 0], alpha=0.5)
plt.savefig('./data/Diff0_dt_dep', dpi = 300)
plt.show()

# %% [markdown]
# ### Иследуем Inexact и Exact методы
# Берем ту же проблему, но теперь локальные подсистемы решаем с разной точностью

# %%
Nd = 5
Nx = 5000
Nt = 10
param ={'Nx': Nx, 'Nt' : Nt}
x = np.linspace(0, 1, Nx)
param ={'Nx': Nx, 'Nt' : Nt}
D = Diffusion(Nx, 0.9, 1, 0.2e-1, model=model)
x0 = np.exp(-x)*np.cos(3*np.pi/2*x)**2
x0 = x0.reshape(-1, 1)

prob = one_phase(D, param)
solver = fxbd_1D(param, prob)
solver.setBoundary(bd1, bd2)
solver.setSources([0.7], [-0.8])
solver.setInitial(x0)

# %%
partion = pt.partion_equally(Nx, Nd)
nl_solver = aspen(Nd, partion, crit_abs = 1e-6)
solver.setSolver(nl_solver)

# %%
time = np.zeros(15)
delta = np.zeros(15)
gb_iters = np.zeros((15, Nt))
lc_iters = np.zeros((15, Nd, Nt))

i = 0
for crit_rel in np.logspace(-5, -0.05, 15):
    nl_solver = aspen(Nd, partion, newton_crit_rel = crit_rel)
    solver.setSolver(nl_solver)
    _, mes, time[i], delta[i] = test(solver, sample_size=4)
    gb_iters[i, :] = solver.timelog.aspen_iters
    lc_iters[i, :, :] = solver.timelog.domain_iters
    if(mes != 'OK'):
        print(i, mes)
    i += 1
# Out:
# test started
# verdict : OK
# time : 78.48 +- 0.8539
# mean aspen iterations:  3.7
# test started
# verdict : OK
# time : 80.05 +- 1.772
# mean aspen iterations:  3.7
# test started
# verdict : OK
# time : 73.64 +- 0.2891
# mean aspen iterations:  3.7
# test started
# verdict : OK
# time : 72.63 +- 0.262
# mean aspen iterations:  3.7
# test started
# verdict : OK
# time : 73.3 +- 1.293
# mean aspen iterations:  3.7
# test started
# verdict : OK
# time : 78.6 +- 1.598
# mean aspen iterations:  3.6
# test started
# verdict : OK
# time : 75.7 +- 0.3704
# mean aspen iterations:  3.6
# test started
# verdict : OK
# time : 73.79 +- 2.067
# mean aspen iterations:  3.6
# test started
# verdict : OK
# time : 85.95 +- 1.772
# mean aspen iterations:  3.6
# test started
# verdict : OK
# time : 83.05 +- 0.9029
# mean aspen iterations:  3.6
# test started
# verdict : OK
# time : 82.5 +- 0.6359
# mean aspen iterations:  3.6
# test started
# verdict : OK
# time : 80.67 +- 0.4671
# mean aspen iterations:  3.6
# test started
# verdict : OK
# time : 78.35 +- 0.3407
# mean aspen iterations:  3.5
# test started
# verdict : OK
# time : 76.22 +- 0.3355
# mean aspen iterations:  3.4
# test started
# verdict : OK
# time : 71.99 +- 0.4341
# mean aspen iterations:  3.2

# %%
crit_rel = np.logspace(-5, -0.05, 15)

plt.title('ASPIN, eps=1e-6')
plt.ylabel('time, s')
plt.xlabel(r'$\varepsilon_{local}$')
plt.xscale('log')
plt.axhline(95.25, color='g', label='ASPEN')
plt.axhline(56.42, color='r', label='Newton')
plt.plot(crit_rel, time, label='ASPIN')
plt.fill_between(crit_rel, time+np.sqrt(delta),
                time-np.sqrt(delta), alpha=0.5)
plt.savefig('./data/Diff0_I_time', dpi=400)
plt.legend()
plt.show()

plt.title('ASPIN')
plt.ylabel('overall local iterations')
plt.xlabel(r'$\varepsilon_{local}$')
plt.xscale('log')
plt.scatter(crit_rel[:-1], np.sum(np.sum(lc_iters, axis = 1)[:-1], axis = 1))
plt.savefig('./data/Diff0_I_lc_iters', dpi=400)
plt.show()

# %%
plt.title(r'$\varepsilon_{lc}$ = 1e-4, step = 0')
plt.bar(np.arange(1, 6), lc_iters[0, :, 0])
plt.savefig('ASpin1', dpi=400)
plt.show()
plt.title(r'$\varepsilon_{lc}$ = 1e-1, step = 0')
plt.ylim(0, 6)
plt.bar(np.arange(1, 6), lc_iters[-1, :, 0])
plt.savefig('ASpin2', dpi=400)
plt.show()

plt.title(r'$\varepsilon_{lc}$ = 1e-4, step = 5')
plt.bar(np.arange(1, 6), lc_iters[0, :, 5])
plt.savefig('ASpin3', dpi=400)
plt.show()
plt.title(r'$\varepsilon_{lc}$ = 1e-1, step = 5')
plt.ylim(0, 5)
plt.bar(np.arange(1, 6), lc_iters[-1, :, 5])
plt.savefig('ASpin4', dpi=400)
plt.show()
