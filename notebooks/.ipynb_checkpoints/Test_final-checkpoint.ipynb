# %%
# importing moudles
# and using some magic to autoreload them if changed
# %load_ext autoreload
# %autoreload 2

import sys

sys.path.append('../nonlin')
sys.path.append('../partion')
sys.path.append('../1D-difusion')

from aspen import aspen
from newton import newton

import partion
from partion import metrics1, metrics2, m1, m2, m3
import wrapper

from one_phase import one_phase
import numpy as np
import matplotlib.pyplot as plt

test = wrapper.test_decorator(wrapper.test)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Построение доменов по параметрам диффузии

# %%
# model to be considered
# we will vary only permability parameter
def model(u):
    return np.array([u**2+1, 2*max(u, 0)])

class Diffusion():
    def __init__(self, Nx, Amp=0, Period=0, Scale=1, model=None):
        self.val = np.zeros((Nx+1, 1))
        for i in range(Nx+1):
            self.val[i] = (
                Amp * np.sin(Period * 2*np.pi * (i+1) / (Nx+1)) + 1) * Scale
        self.model = model

# %% [markdown]
# Мы будем рассматривать следующий класс задач: зафиксированные границы (0, 1), начальное условие - прямая $u = x$, пронциаемость среды модулируем случайными синусоидами

# %%
Nx = 500
Nt = 50
D = Diffusion(Nx, model=model)
bd1 = 0
bd2 = 1
x0 = np.arange(Nx)/(Nx-1)
x0 = np.reshape(x0, (-1, 1))

# %% [markdown]
# Мы будем строить домены по экстремумам пронциаемости среды, ожидается что на участках с разной производной будет разная динамика потоков

# %%
def borders_df(D):
    bd_df = [0]
    for i in range(1, Nx):
        if(np.sign(D.val[i]-D.val[i-1])*np.sign(D.val[i+1]-D.val[i]) < 0 ):
            bd_df.append(i)
    bd_df.append(Nx)
    return bd_df

# %%
param = {
    'Nx': Nx, 
    'Nt': Nt,
}

N = 10
t_new = np.zeros(N)
t_as = np.zeros(N)
t_eq = np.zeros(N)
for i in range(N):
    # permebility distribuition
    D.val = np.zeros((Nx+1, 1))
    for k in range(5):
        T = np.random.randint(1, 5)
        amp = np.random.random()
        D.val += amp*np.sin(T * 2*np.pi * np.linspace(0, 1, Nx+1)).reshape(-1, 1)
    D.val /= np.max(np.abs(D.val))+1e-2
    D.val = 1 + D.val
    '''
    plt.plot(D.val)
    plt.show()
    '''
    
    nl_solver = newton(1e-2, kmax = 14, crit_abs = 1e-3)
    solver_cl = one_phase(param, D, nl_solver)
    solver_cl.x0 = np.copy(x0)
    solver_cl.setBoundary(bd1, bd2)
    _, _, _, t = wrapper.test(solver_cl, sample_size = 3)
    t_new[i] = t
    
    part = borders_df(D)
    Nd = len(part)-1
    nl_solver = aspen(Nd, part, 1e-2, crit_abs = 1e-3)
    solver_as = one_phase(param, D, nl_solver)
    solver_as.x0 = np.copy(x0)
    solver_as.setBoundary(bd1, bd2)
    _, _, _, t = wrapper.test(solver_cl, sample_size = 3)
    t_as[i] = t
    
    Nd = 5
    part = partion.partion_equally(Nx, Nd)
    nl_solver = aspen(Nd, part, 1e-2, crit_abs = 1e-3)
    solver_as = one_phase(param, D, nl_solver)
    solver_as.x0 = np.copy(x0)
    solver_as.setBoundary(bd1, bd2)
    _, _, _, t = wrapper.test(solver_cl, sample_size = 3)
    t_eq[i] = t

# %%
plt.style.use('dark_background')
plt.title('ASPEN')
plt.plot(t_as/t_new, label='diffusion inspired partion')
plt.plot(t_eq/t_new, label='equally, Nd = 5')
plt.ylabel('$t$/$t_{new}$')
plt.legend()
plt.savefig('./data/diff_part', dpi = 400)
plt.show()

# %% [markdown]
# ### Построение доменов через разбиение графа
# Две формулировки функции на минимизацию:
# $$
#     vol(\partial S_i) = \sum_{v \in V_i} \sum_{u \in \Gamma(v), u \notin V_i} {w(v, u)}
# $$
# Первый способ:$$
# \sum \frac{vol(\partial S_i)}{| V_i|} \rightarrow \min
# $$Второй способ:$$
# \sum \frac{vol(\partial S_i)}{vol(V_i)} \rightarrow \min
# $$где $vol(V_i) = \sum_{u, v \in V_i} w(u, v)$

# %% [markdown]
# ## Задача 1
# Сперва рассмотрим задачу с фиксированными концами (0, 1), для которой известны начальные условия и параметры диффузии. Сравним между собой метрики на ней

# %%
# inital condition
Nx = 1000
Nt = 100
D = Diffusion(Nx, 0.9, 1, 0.5e-1, model=model)
bd1 = 0
bd2 = 1
x0 = np.arange(Nx)/(Nx-1)
x0 = np.sinh(20*(x0-0.5))
x0 /= np.max(x0)
x0 = (x0+1)/2
x0 = np.reshape(x0, (-1, 1))
plt.xlabel('x0')
plt.ylabel('u')
plt.plot(x0)

# %%
param = {
    'Nx': Nx, 
    'Nt': Nt,
}
nl_solver = newton(1e-2, kmax = 14, crit_abs = 1e-3)
solver_cl = one_phase(param, D, nl_solver)
solver_cl.x0 = np.copy(x0)
solver_cl.setBoundary(bd1, bd2)
X_cl, message, t_new = test(solver_cl, sample_size = 1)
# Out:
# test started
# verdict : OK
# mean time : 52.95842909812927
# mean newton iterations:  4.11

# %%
# we will store resuts there
results1 = {}

# %%
A1 = np.zeros((Nx, Nx))
A2 = np.zeros((Nx, Nx))
A3 = np.zeros((Nx, Nx))
M = 5
du = 1e-2
for i in range(M):
    step = Nt//M
    Jf = partion.precompute_Jf(solver_cl, X_cl[:, i*step], Nx)
    Jf_n = partion.precompute_Jf(solver_cl, X_cl[:, i*step]+du, Nx)
    f1 = lambda k, m: m1(solver_cl, Jf, k, m)
    f3 = lambda k, m: m3(solver_cl, Jf, Jf_n, k, m)
    B = partion.adj_matrix(f1, Nx)
    B /= np.max(B)
    A1 += B
    B = partion.adj_matrix(f3, Nx)
    B /= np.max(B)
    A3 += B
f2 = lambda k, m: m2(X_cl, k, m)
A2 = partion.adj_matrix(f2, Nx)
A1 /= M
A3 /= M

# %%
Nd = 4
results1['bd_m1'] = partion.domain_builder2(A1, Nd, inv = False, k = Nd)
results1['bd_m2'] = partion.domain_builder2(A2, Nd, inv = True, k = Nd)
results1['bd_m3'] = partion.domain_builder2(A3, Nd, inv = False, k = Nd)

for bd, A, metrics in zip([results1['bd_m1'], results1['bd_m2'],
    results1['bd_m3']], [A1, A2, A3], [partion.metrics1, partion.metrics2, partion.metrics1]):
    print(bd)
    print('eq : {}'.format(metrics(
    partion.partion_equally(Nx, Nd), A)))
    print('spec : {}'.format(metrics(
    bd, A)))
# Out:
# [   0  163  355  607 1000]
# eq : 0.004668239795785708
# spec : 0.0017332906129836282
# [   0  206  500  794 1000]
# eq : 0.0030092651147689844
# spec : 0.002923273329724924
# [   0  150  439  755 1000]
# eq : 0.007378778736895094
# spec : 0.007209640790731836

# %%
borders = results1['bd_m1']

Nd = 4
param = {
    'Nx': Nx, 
    'Nt': Nt
}
nl_solver = aspen(Nd, borders, 1e-2, crit_abs = 1e-3)
solver_as = one_phase(param, D, nl_solver)
solver_as.x0 = np.copy(x0)
solver_as.setBoundary(bd1, bd2)
X, message, t = test(solver_as, sample_size = 5)
results1['t_m1'] = np.copy(t)
wrapper.show_res(solver_as)
# Out:
# test started
# verdict : OK
# mean time : 39.26408290863037
# mean aspen iterations:  1.05
# iters : [6.47 1.05 1.   1.06]

# %%
borders = results1['bd_m2']

Nd = 4
param = {
    'Nx': Nx, 
    'Nt': Nt
}
nl_solver = aspen(Nd, borders, 1e-2, crit_abs = 1e-3)
solver_as = one_phase(param, D, nl_solver)
solver_as.x0 = np.copy(x0)
solver_as.setBoundary(bd1, bd2)
X, message, t = test(solver_as, sample_size = 5)
results1['t_m2'] = np.copy(t)
wrapper.show_res(solver_as)
# Out:
# test started
# verdict : OK
# mean time : 39.88854789733887
# mean aspen iterations:  1.0
# iters : [6.11 1.   1.   1.01]

# %%
borders = results1['bd_m3']

Nd = 4
param = {
    'Nx': Nx, 
    'Nt': Nt
}
nl_solver = aspen(Nd, borders, 1e-2, crit_abs = 1e-3)
solver_as = one_phase(param, D, nl_solver)
solver_as.x0 = np.copy(x0)
solver_as.setBoundary(bd1, bd2)
X, message, t = test(solver_as, sample_size = 5)
results1['t_m3'] = np.copy(t)
wrapper.show_res(solver_as, save = './data/m3_Nd4')
wrapper.compare([solver_cl, solver_as], ['newton', 'aspen'], save = './data/m3_comp_Nd4')
# Out:
# test started
# verdict : OK
# mean time : 39.23728699684143
# mean aspen iterations:  1.08
# iters : [6.75 1.08 1.   1.09]
# --time comparision--
# newton : 52.92430138587952
# aspen : 39.33380627632141

# %%
borders = partion.partion_equally(Nx, Nd)

Nd = 4
param = {
    'Nx': Nx, 
    'Nt': Nt
}
nl_solver = aspen(Nd, borders, 1e-2, crit_abs = 1e-3)
solver_as = one_phase(param, D, nl_solver)
solver_as.x0 = np.copy(x0)
solver_as.setBoundary(bd1, bd2)
X, message, t = test(solver_as, sample_size = 5)
results1['t_eq'] = np.copy(t)
wrapper.show_res(solver_as)
# Out:
# test started
# verdict : OK
# mean time : 41.98502383232117
# mean aspen iterations:  1.0
# iters : [6.09 1.   1.   1.01]

# %%
import csv
gather_data = False

Nd = 4
if gather_data:
    N = 20
    param = {
        'Nx': Nx, 
        'Nt': Nt
    }

    time = np.zeros(N)
    borders = np.zeros((Nd-1, N), dtype = 'int')
    num_of_alghs = 0

    for k in range(N):
        part = partion.generate_fr_eq(Nx, Nd)
        borders[:, k] = part[1:-1]
        nl_solver = aspen(Nd, part, 1e-2, crit_abs = 1e-3)
        solver_ts = one_phase(param, D, nl_solver)
        solver_ts.setBoundary(bd1, bd2)
        solver_ts.x0 = np.copy(x0)
        _, _, _, t = wrapper.test(solver_ts, sample_size = 1)
        if(message != 'OK'):
            continue
        time[k] = t
        num_of_alghs += 1
        if k % 10 == 0:
            print(k)      
    # save data
    name = './data/Nx={},Nt={},Nd={}.csv'.format(Nx, Nt, Nd)
    filt = time > 0
    with open(name, 'a') as csvfile:
        writer = csv.writer(csvfile, delimiter=',')
        writer.writerows(borders[:, filt])
        writer.writerow(time[filt])
else:
    name = './data/Nx={},Nt={},Nd={}.csv'.format(Nx, Nt, Nd)
    with open(name, 'r') as csvfile:
        reader = csv.reader(csvfile)
        data = []
        for row in reader:
            data.append(row)        
        borders = np.array(data[0:Nd-1], dtype='int')
        time = np.array(data[Nd-1], dtype= 'float')
        num_of_alghs = np.sum(time > 0)

# %%
print('Numner og alghorithms that converged:', num_of_alghs)
print('mean time :', np.sum(time)/num_of_alghs)
sq_cov = np.sqrt(np.sum(time**2)/num_of_alghs-(np.sum(time)/num_of_alghs)**2)
print('sqrt cov :', np.sqrt(np.sum(time**2)/num_of_alghs-(np.sum(time)/num_of_alghs)**2))
# Out:
# Numner og alghorithms that converged: 40
# mean time : 44.27139791250229
# sqrt cov : 3.5798446666350903

# %%
from scipy.stats import gaussian_kde
from scipy.integrate import quad

width = 2
win = np.arange(5, 155, width)
y = []
for x in win:
    mask = ((time < x+width/2) & (time > (x - width/2)))
    y.append(np.sum(mask)/ num_of_alghs/5)
    
plt.bar(win, y, width=width*0.5, color = 'r')
bw = 1/(1.06*sq_cov)*num_of_alghs**(1/5)
filt = time > 0
kernel = gaussian_kde(time[filt], bw_method=bw)

plt.plot(np.linspace(30, 80, 100), kernel(np.linspace(30, 80, 100)))
plt.xlim((35, 55))
plt.axvline(t_new, label='newton', linestyle ='--', color='y')
plt.axvline(results1['t_eq'], label='eq', linestyle ='--', color='c')
#plt.axvline(results1['t_m1'], label='m1', linestyle ='--', color ='r')
plt.axvline(results1['t_m2'], label='m2', linestyle ='--', color ='g')
plt.axvline(results1['t_m3'], label='m1, m3', linestyle ='--', color ='w')
plt.xlabel('t, s')
plt.ylabel('p')
plt.legend()
plt.savefig('./data/Prob1,4_dist', dpi = 400)
plt.show()

# %%
filt = np.logical_and(time > 0, time < 90)
m1_list = []
m2_list = []
m3_list = []

# Matrix of Weights
# Matrix of Weights
M = 5
A1 = np.zeros((Nx, Nx))
A3 = np.zeros((Nx, Nx))
du = 1e-2
for i in range(M):
    step = Nt//M
    Jf = partion.precompute_Jf(solver_cl, X_cl[:, i*step], Nx)
    Jf_n = partion.precompute_Jf(solver_cl, X_cl[:, i*step]+du, Nx)
    func = lambda i, j: m1(solver_cl, Jf, i, j)
    B = partion.adj_matrix(func, Nx)
    B /= np.max(B)
    A1 += B
    func = lambda k, m: m3(solver_cl, Jf, Jf_n, k, m)
    B = partion.adj_matrix(func, Nx)
    #B /= np.max(B)
    A3 += B
A1 /= M
A3 /= M
func = lambda i, j: m2(X_cl, i, j)
A2 = partion.adj_matrix(func, Nx)

func1 = lambda borders: partion.metrics1(borders, A1)
func2 = lambda borders: partion.metrics2(borders, A2)
func3 = lambda borders: partion.metrics2(borders, A3)
for domain in borders[:, filt].T:
    part = np.concatenate(([0], domain, [Nx]), axis = 0)
    m1_list.append(func1(part))
    m2_list.append(func2(part))
    m3_list.append(func3(part))

m1_arr = np.array(m1_list)
m2_arr = np.array(m2_list)
m3_arr = np.array(m3_list)

cov_m1 = np.cov(np.stack((time[filt], m1_arr) , axis = 0))

cov_m2 = np.cov(np.stack((time[filt], m2_arr) , axis = 0))

cov_m3 = np.cov(np.stack((time[filt], m3_arr) , axis = 0))

fig, axs = plt.subplots(1, 3, figsize=(12, 4), sharey=True)
fig.suptitle('Metrics comparision. Search efficency')
axs[0].scatter(m1_arr, time[filt])
#plt.legend()
axs[0].set_xscale('log')
axs[0].set_title('corr: {:.2E}'.format(cov_m1[1, 0]/np.sqrt(cov_m1[0, 0]*cov_m1[1, 1])))
axs[0].set_xlabel('m1')
axs[0].set_ylabel('t, s')
#plt.legend()
axs[1].scatter(m2_arr, time[filt])
axs[1].set_xscale('log')
axs[1].set_title('corr: {:.2E}'.format(cov_m2[1, 0]/np.sqrt(cov_m2[0, 0]*cov_m2[1, 1])))
axs[1].set_xlabel('m2')
axs[1].set_ylabel('t, s')
#plt.legend()
axs[2].scatter(m3_arr, time[filt])
axs[2].set_xscale('log')
axs[2].set_title('corr: {:.2E}'.format(cov_m3[1, 0]/np.sqrt(cov_m3[0, 0]*cov_m3[1, 1])))
axs[2].set_xlabel('m3')
axs[2].set_ylabel('t, s')
plt.savefig('./data/Prob1,4_corr', dpi = 400)
plt.show()

# %% [markdown]
# Исследуем задачу на оптимальное число доменов

# %%
mean_time = np.zeros((30, 4))
var = np.zeros((30, 4))

param = {
        'Nx': Nx, 
        'Nt': Nt
}

for k in range(3, 12):
    Nd = k
    borders1 = partion.domain_builder2(A1, Nd, inv = False, k = Nd)
    borders2 = partion.domain_builder2(A2, Nd, inv = True, k = Nd)
    borders3 = partion.domain_builder2(A3, Nd, inv = True, k = Nd)
    borders4 = partion.partion_equally(Nx, Nd)
    print(borders1, borders3)

    for bd, i in zip([borders1, borders2, borders3, borders4], [0, 1, 2, 3]):
        nl_solver = aspen(Nd, bd, 1e-2, crit_abs = 1e-3)
        solver_as = one_phase(param, D, nl_solver)
        solver_as.x0 = np.copy(x0)
        solver_as.setBoundary(bd1, bd2)
        t = np.zeros(5)
        for j in range(5):
            _, _, mes, t[j] = wrapper.test(solver_as, sample_size = 1)
            
        var[k, i] = np.var(t)
        mean_time[k, i] = np.mean(t)
    
        if mes != 'OK':
            print(k, i, 'did not converged')
# Out:
# [   0  194  532 1000] [   0  245  665 1000]
# [   0  162  362  615 1000] [   0  151  440  756 1000]
# [   0  138  313  501  869 1000] [   0  104  319  554  808 1000]
# [   0  115  255  389  561  891 1000] [   0   77  245  433  631  843 1000]
# [   0   97  216  324  440  598  900 1000] [   0   59  194  349  513  683  867 1000]
# [   0   85  189  282  375  478  627  908 1000] [   0   47  158  289  428  573  722  884 1000]
# [   0   76  170  254  335  421  520  671  921 1000] [   0   39  133  245  365  490  619  752  897 1000]
# [   0   70  157  234  309  387  475  590  810  942 1000] [   0   33  114  211  316  426  540  656  777  908 1000]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-159-94875592291f> in <module>
#      12     borders1 = partion.domain_builder2(A1, Nd, inv = False, k = Nd)
#      13     #borders2 = partion.domain_builder2(A2, Nd, inv = True, k = Nd)
# ---> 14     borders3 = partion.domain_builder2(A3, Nd, inv = True, k = Nd)
#      15     #borders4 = partion.partion_equally(Nx, Nd)
#      16     print(borders1, borders3)
#
# ~/Рабочий стол/aspen-study/partion/partion.py in domain_builder2(A, Nd, inv, k)
#     191     '''
#     192
# --> 193     kmeans = KMeans(n_clusters=Nd, random_state=0).fit(v)
#     194     lb = kmeans.labels_
#     195     #print(kmeans.cluster_centers_)
#
# ~/miniconda3/envs/py3_study/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py in fit(self, X, y, sample_weight)
#    1070                 init=init, verbose=self.verbose, tol=self._tol,
#    1071                 x_squared_norms=x_squared_norms, random_state=seed,
# -> 1072                 n_threads=self._n_threads)
#    1073             # determine if these results are the best so far
#    1074             if best_inertia is None or inertia < best_inertia:
#
# ~/miniconda3/envs/py3_study/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py in _kmeans_single_elkan(X, sample_weight, n_clusters, max_iter, init, verbose, x_squared_norms, random_state, tol, n_threads)
#     426         # compute new pairwise distances between centers and closest other
#     427         # center of each center for next iterations
# --> 428         center_half_distances = euclidean_distances(centers_new) / 2
#     429         distance_next_center = np.partition(
#     430             np.asarray(center_half_distances), kth=1, axis=0)[1]
#
# ~/miniconda3/envs/py3_study/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/miniconda3/envs/py3_study/lib/python3.7/site-packages/sklearn/metrics/pairwise.py in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     267     paired_distances : distances betweens pairs of elements of X and Y.
#     268     """
# --> 269     X, Y = check_pairwise_arrays(X, Y)
#     270
#     271     # If norms are passed as float32, they are unused. If arrays are passed as
#
# ~/miniconda3/envs/py3_study/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/miniconda3/envs/py3_study/lib/python3.7/site-packages/sklearn/metrics/pairwise.py in check_pairwise_arrays(X, Y, precomputed, dtype, accept_sparse, force_all_finite, copy)
#     141         X = Y = check_array(X, accept_sparse=accept_sparse, dtype=dtype,
#     142                             copy=copy, force_all_finite=force_all_finite,
# --> 143                             estimator=estimator)
#     144     else:
#     145         X = check_array(X, accept_sparse=accept_sparse, dtype=dtype,
#
# ~/miniconda3/envs/py3_study/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/miniconda3/envs/py3_study/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     596                     array = array.astype(dtype, casting="unsafe", copy=False)
#     597                 else:
# --> 598                     array = np.asarray(array, order=order, dtype=dtype)
#     599             except ComplexWarning:
#     600                 raise ValueError("Complex data not supported\n"
#
# ~/miniconda3/envs/py3_study/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      12 ]
#      13
# ---> 14 @set_module('numpy')
#      15 def asarray(a, dtype=None, order=None):
#      16     """Convert the input to an array.
#
# KeyboardInterrupt:

# %%
# 3, -2
end = 9
for name, i in zip(['m1', 'm2', 'm3', 'eq'], [0, 1, 2, 3]):
    plt.plot(np.arange(3, end), mean_time[3:end, i]/t_new, label=name)
    plt.xlabel('Number of domains')
    plt.ylabel('t/$t_{new}$')
    tmp = np.sqrt(var[3:end, i])/t_new
    plt.fill_between(np.arange(3, end), mean_time[3:end, i]/t_new-tmp, 
                     mean_time[3:end, i]/t_new+tmp, alpha=0.5)
    plt.legend()
plt.savefig('./data/cmp222', dpi = 400)
plt.show()

# %%
w1, _ = partion.spec_bis(A1, inv = False, k = 17)
w2, _ = partion.spec_bis(A2, inv = True, k = 17)
w3, _ = partion.spec_bis(A3, inv = False, k = 17)

# %%
def linear(x, a, b):
    return x*a+b
from scipy.optimize import curve_fit

x = np.arange(1, 17)
plt.axvline(np.log(7), label='opt domain number')
plt.xlabel('$\log(N)$')
plt.ylabel('$\log(\lambda)$')
plt.plot(np.log(x), np.log(w1[1:]), label='m1')
plt.plot(np.log(x), np.log(w2[1:]), label='m2')
plt.plot(np.log(x), np.log(w3[1:]), label='m3')
plt.legend()
popt, pcov = curve_fit(linear, np.log(x), np.log(w1[1:]))
print(popt[0])
plt.show()
# Out:
# 2.0152367527319686

# %%
aspen_time = np.zeros(10)
aspen_iters = np.zeros(10)
local_iters = np.zeros((10, 7))
borders = partion.partion_equally(Nx, Nd)
for i in range(10):
    Nt = 50*(1+i)
    param = {
        'Nx': Nx, 
        'Nt': Nt,
    }
    nl_solver = aspen(7, borders, 1e-2, max_lc = 14, crit_abs = 1e-3)
    solver_as = one_phase(param, D, nl_solver)
    solver_as.x0 = np.copy(x0)
    solver_as.setBoundary(bd1, bd2)
    _, _, message, t = wrapper.test(solver_as, x0, sample_size = 1)
    
    aspen_time[i] = t
    aspen_iters[i] = np.sum(solver_as.timelog.aspen_iters)/Nt
    local_iters[i, :] = solver_as.timelog.domain_iters
    if message != 'OK':
        print(i, 'not converged')

# %% [markdown]
# ### Задача 2

# %%
plt.style.use('dark_background')
# inital condition
Nx = 1000
Nt = 50
D = Diffusion(Nx, 0.9, 1, 0.5e-1, model=model)
x = np.linspace(0, 1, Nx+1).reshape(-1, 1)
D.val *= 1 + x*(1-x)
bd1 = 0
bd2 = 1
x = np.linspace(0, 1, Nx)
x0 = np.exp(-x/2)*np.cos(3*np.pi/2*x)**2
x0 = x0[::-1]
x0 = np.reshape(x0, (-1, 1))
plt.xlabel('x0')
plt.ylabel('u')
plt.plot(x0)
plt.show()

setSources = lambda x: x.setSources([2/3], [-30])

# %%
results2 = {}
param = {
    'Nx': Nx, 
    'Nt': Nt,
}
nl_solver = newton(1e-2, kmax = 14, crit_abs = 1e-3)
solver_cl = one_phase(param, D, nl_solver)
solver_cl.x0 = np.copy(x0)
solver_cl.setBoundary(bd1, bd2)
setSources(solver_cl)
X_cl, message, t = test(solver_cl, sample_size = 1)

results2['t_new'] = np.copy(t)

wrapper.show_res(solver_cl)
# Out:
# test started
# verdict : OK
# mean time : 32.9767324924469
# mean newton iterations:  4.98

# %%
Nd = 7
borders = partion.partion_equally(Nx, Nd)

param = {
    'Nx': Nx, 
    'Nt': Nt
}
nl_solver = aspen(Nd, borders, 1e-2, crit_abs = 1e-3)
solver_as = one_phase(param, D, nl_solver)
solver_as.x0 = np.copy(x0)
solver_as.setBoundary(bd1, bd2)
setSources(solver_as)
X, message, t = test(solver_as, sample_size = 1)
results2['t_eq'] = np.copy(t)
wrapper.show_res(solver_as)
wrapper.compare([solver_cl, solver_as], ['newton', 'aspen'])
# Out:
# test started
# verdict : OK
# mean time : 29.223172903060913
# mean aspen iterations:  1.92
# iters : [13.44  1.22  1.34  1.3   1.42  1.34  1.18]
# --time comparision--
# newton : 32.95503616333008
# aspen : 29.14959192276001

# %%
import time
def border_changer(solver, X, Nd):
    Jf = partion.precompute_Jf(solver, X[:, -1], Nx)
    Jf_n = partion.precompute_Jf(solver, X[:, -1]+1e-2, Nx)
    func1 = lambda k, m: m3(solver, Jf, Jf_n, k, m)
    A1 = partion.adj_matrix(func1, Nx)
    return partion.domain_builder2(A1, Nd, inv = False, k = Nd)

Nd = 6
borders = partion.partion_equally(Nx, Nd)
param = {
    'Nx': Nx, 
    'Nt': Nt
}
nl_solver = aspen(Nd, borders, 1e-2, crit_abs = 1e-3)
solver_as = one_phase(param, D, nl_solver, bd_ch = border_changer)
solver_as.x0 = np.copy(x0)
setSources(solver_as)
solver_as.setBoundary(bd1, bd2)
X, message, t = test(solver_as, sample_size = 1)
results2['t_m1'] = np.copy(t)
# Out:
# test started
# 0.08143067359924316
# 0.09981608390808105
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-382-93fb120b27e0> in <module>
#      21 setSources(solver_as)
#      22 solver_as.setBoundary(bd1, bd2)
# ---> 23 X, message, t = test(solver_as, sample_size = 1)
#      24 results2['t_m1'] = np.copy(t)
#
# ~/Рабочий стол/aspen-study/notebooks/wrapper.py in wraper(*args, **kwargs)
#      18     def wraper(*args, **kwargs):
#      19         print('test started')
# ---> 20         solver, X, mes, t = obj(*args, **kwargs)
#      21         print('verdict : ' + mes)
#      22         print('mean time : {}'.format(t))
#
# ~/Рабочий стол/aspen-study/notebooks/wrapper.py in test(solver, sample_size)
#      35         solver.init_log()
#      36         t -= time.time()
# ---> 37         X, mes = solver.solve()
#      38         t += time.time()
#      39     t /= sample_size
#
# ~/Рабочий стол/aspen-study/1D-difusion/one_phase.py in solve(self)
#     120                 self.solver.init_log()
#     121
# --> 122             X, mes = self.solver.solve(X)
#     123
#     124             if not(mes):
#
# ~/Рабочий стол/aspen-study/nonlin/aspen.py in solve(self, X)
#      79
#      80                 self.buf[:end-start] = X[start:end]
# ---> 81                 self.X_l[start:end], mes = self.newton.solve(X, aspen = True)
#      82
#      83                 X[start:end] = self.buf[:end-start]
#
# ~/Рабочий стол/aspen-study/nonlin/newton.py in solve(self, X, aspen)
#      32             # residual
#      33             t_res = - time()
# ---> 34             R = self.f.val(X)
#      35             t_res += time()
#      36
#
# ~/Рабочий стол/aspen-study/nonlin/aspen.py in val(self, X)
#      36             self.end = end
#      37         def val(self, X):
# ---> 38             return self.f.val(X, self.start, self.end)
#      39         def jac(self, X):
#      40             return self.f.jac(X, self.start, self.end)
#
# ~/Рабочий стол/aspen-study/1D-difusion/one_phase.py in val(self, X, st, end)
#     242
#     243             for i in range(st, end):
# --> 244                 self.Rx[i, :] = self.res_f(X, i)
#     245
#     246             return self.Rt[st:end]/self.dt + self.Rx[st:end] + self.outer.q[st:end]
#
# KeyboardInterrupt:

# %%
wrapper.show_res(solver_as)
wrapper.compare([solver_cl, solver_as], ['newton', 'aspen'])
# Out:
# iters : [14.98  1.32  1.42  1.42  1.6   1.28]
# --time comparision--
# newton : 32.95503616333008
# aspen : 32.177910566329956
