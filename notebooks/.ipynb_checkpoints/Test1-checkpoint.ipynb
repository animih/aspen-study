# %%
# %load_ext autoreload
# %autoreload 2

import sys

sys.path.append('../nonlin')
sys.path.append('../partion')
sys.path.append('../1D-difusion')

from aspen import aspen
from newton import newton

import partion
from partion import metrics1, metrics2, m1, m2, m3
import wrapper

from one_phase import one_phase
import numpy as np
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Начальные условия и модель

# %%
def model(u):
    return np.array([u**2+1, 2*max(u, 0)])

class Diffusion():
    def __init__(self, Nx, Amp=0, Period=0, Scale=1, model=None):
        self.val = np.zeros((Nx+1, 1))
        for i in range(Nx+1):
            self.val[i] = (
                Amp * np.sin(Period * 2*np.pi * (i+1) / (Nx+1)) + 1) * Scale
        self.model = model

# %%
plt.style.use('dark_background')
# inital condition
Nx = 1000
Nt = 100
D = Diffusion(Nx, 0.9, 1, 0.5e-1, model=model)
bd1 = 0
bd2 = 1
x0 = np.arange(Nx)/(Nx-1)
x0 = np.sinh(20*(x0-0.5))
x0 /= np.max(x0)
x0 = (x0+1)/2
x0 = np.reshape(x0, (-1, 1))
plt.xlabel('x0')
plt.ylabel('u')
plt.plot(x0)

# %% [markdown]
# Такое начальное условие выбрано для динамики, позднее на графиках будет видно как решение меняется по времени

# %%
test = wrapper.test_decorator(wrapper.test)

# %%
param = {
    'Nx': Nx, 
    'Nt': Nt,
}
nl_solver = newton(1e-2, kmax = 14, crit_abs = 1e-3)
solver_cl = one_phase(param, D, nl_solver)
solver_cl.x0 = np.copy(x0)
solver_cl.setBoundary(bd1, bd2)
X_cl, message, t_new = test(solver_cl, x0, sample_size = 5)
# Out:
# test started
# verdict : OK
# mean time : 61.849143743515015
# mean newton iterations:  4.11

# %%
Nd = 5
param = {
    'Nx': Nx, 
    'Nt': Nt
}
part = partion.partion_equally(Nx, Nd)
nl_solver = aspen(Nd, part, 1e-2, crit_abs = 1e-3)
solver_as = one_phase(param, D, nl_solver)
solver_as.x0 = np.copy(x0)
solver_as.setBoundary(bd1, bd2)
X, message, t_eq = test(solver_as, x0, sample_size = 5)
# Out:
# test started
# verdict : OK
# mean time : 46.94906678199768
# mean aspen iterations:  1.0

# %% [markdown]
# ### Графики решения

# %%
wrapper.show_res(solver_cl)
wrapper.show_res(solver_as)
x = np.linspace(0, 1, Nx)

plt.title('Diff')
plt.xlabel('x')
plt.ylabel('t')
t = solver_as.t
x_grid, t_grid = np.meshgrid(x, t)
cs = plt.contourf(x_grid, t_grid, (np.abs(X-X_cl)).T, cmap='RdBu_r')
cbar = plt.colorbar(cs)
plt.show()
# Out:
# iters : [6.11 1.   1.   1.   1.01]

# %% [markdown]
# Как видим а) присутсвует динамика по времени, имеющая локальный характер, б) решения двух алгоритмов отличаются в пределах погрешности

# %%
wrapper.compare([solver_cl, solver_as], ['newton', 'aspen'])
# Out:
# --time comparision--
# newton : 64.9014344215393
# aspen : 46.650580406188965

# %% [markdown]
# Хм, похоже что ускорения получилось добиться незначительного

# %% [markdown]
# Почти везде aspen справляется за одну иттерацию, когда метод Ньютона работает долго на начальных этапах задачи. Скорей всего, продолжи мы решения даже, вышли бы уже на почти стационарный участоток, где требуется мало иттераций

# %% [markdown]
# Во-первых, тут мы наблюдаем выделние домена с наибольшим число иттераций, во-вторых похоже что среднее число иттераций в нем превосходит среднее число иттераций в методе Ньютона, что еще раз подвтерждает версию о том, что ASPEN был эффективен на начальных этапах задачи. Вероятно, надо учиться делать динамические границы

# %% [markdown]
# ### Тактики разбиения
# На примере данной задачи будем тестить разные критерии разбиения на домены

# %% [markdown]
# ### Две формулировки функции на минимизацию:
#
# $$
# 	vol(\partial S_i) = \sum_{v \in V_i} \sum_{u \in \Gamma(v), u \notin V_i} {w(v, u)}
# $$
# Первый способ:
# $$
# \sum \frac{vol(\partial S_i)}{| V_i|} \rightarrow \min
# $$
# Второй способ:
# $$
# \sum \frac{vol(\partial S_i)}{vol(V_i)} \rightarrow \min
# $$
# где $vol(V_i) = \sum_{u, v \in V_i} w(u, v)$

# %% [markdown]
# ##### Метод 1
# $$
# w(v, u) =  (|\frac{\partial R(u)}{\partial v}| + |\frac{\partial R(v)}{\partial u}|)^{-1}
# $$

# %%
# we will store borders and time in a dict
results = {}

# %%
# Matrix of Weights
M = 5
A = np.zeros((Nx, Nx))
for i in range(M):
    step = Nt//M
    Jf = partion.precompute_Jf(solver_cl, X_cl[:, i*step], Nx)
    func = lambda i, j: m1(solver_cl, Jf, i, j)
    B = partion.adj_matrix(func, Nx)
    B /= np.max(B)
    A += B
A /= M
plt.matshow(A[150:250, 150:250])
plt.show()

# %%
Nd = 5
borders = partion.domain_builder1(A, Nd, inv = False)
print(borders)

print('--comparison--')
print('eq : {}'.format(partion.metrics1(
    partion.partion_equally(Nx, Nd), A)))
print('spec : {}'.format(partion.metrics1(
    borders, A)))

results['p1_m1_rc'] = np.copy(borders)
# Out:
# [   0  223  367  525  825 1000]
# --comparison--
# eq : 0.004997346446818488
# spec : 0.0030215966554033415

# %%
Nd = 5
borders = partion.domain_builder1(A, Nd, inv = True)
print(borders)

print('--comparison--')
print('eq : {}'.format(partion.metrics2(
    partion.partion_equally(Nx, Nd), A)))
print('spec : {}'.format(partion.metrics2(
    borders, A)))

results['p2_m1_rc'] = np.copy(borders)
# Out:
# [   0   58   63   77  168 1000]
# --comparison--
# eq : 0.011882064226453543
# spec : 0.17334491231390475

# %%
Nd = 5
borders = partion.domain_builder2(A, Nd, inv = False, k = Nd+2)
print(borders)

print('--comparison--')
print('eq : {}'.format(partion.metrics1(
    partion.partion_equally(Nx, Nd), A)))
print('spec : {}'.format(partion.metrics1(
    borders, A)))

results['p1_m1_cl'] = np.copy(borders)
# Out:
# [   0   95  253  402  608 1000]
# --comparison--
# eq : 0.004997346446818488
# spec : 0.0029524298573379002

# %%
Nd = 5
borders = partion.domain_builder2(A, Nd, inv = True, k = Nd+2)
print(borders)

print('--comparison--')
print('eq : {}'.format(partion.metrics2(
    partion.partion_equally(Nx, Nd), A)))
print('spec : {}'.format(partion.metrics2(
    borders, A)))

results['p2_m1_cl'] = np.copy(borders)
# Out:
# [   0  101  286  420  555 1000]
# --comparison--
# eq : 0.011882064226453543
# spec : 0.01626302658490348

# %%
borders = results['p1_m1_rc']

Nd = 5
param = {
    'Nx': Nx, 
    'Nt': Nt
}
bd1 = 0
bd2 = 1
nl_solver = aspen(Nd, borders, 1e-2, crit_abs = 1e-3)
solver_as = one_phase(param, D, nl_solver)
solver_as.x0 = np.copy(x0)
solver_as.setBoundary(bd1, bd2)
X, message, t = test(solver_as, x0, sample_size = 5)

results['t_m1'] = np.copy(t)
# Out:
# test started
# verdict : OK
# mean time : 46.06422872543335
# mean aspen iterations:  1.0

# %%
wrapper.show_res(solver_as)
wrapper.compare([solver_cl, solver_as], ['newton', 'aspen'])
# Out:
# iters : [6.1  1.   1.   1.   1.01]
# --time comparision--
# newton : 64.9014344215393
# aspen : 46.13253998756409

# %% [markdown]
# Похоже, что работает метрика не супер хорошо

# %% [markdown]
# ##### Метод 2
# $$
# w(v, u) = |cov(u, v)|
# $$
# где u, v - столбцы по t

# %%
# Matrix of Weights

func = lambda i, j: m2(solver_cl, X_cl, i, j)
A = partion.adj_matrix(func, Nx, dense = 5)

plt.matshow(A[:10, :10])
plt.matshow(A[650:750, 650:750])

# %%
Nd = 5
borders = partion.domain_builder1(A, Nd, inv = False)
print(borders)

print('--comparison--')
print('eq : {}'.format(partion.metrics1(
    partion.partion_equally(Nx, Nd), A)))
print('spec : {}'.format(partion.metrics1(
    borders, A)))

results['p1_m2_rc'] = np.copy(borders)
# Out:
# [   0  250  375  501  749 1000]
# --comparison--
# eq : 0.4199643135159226
# spec : 0.5033207582375911

# %%
Nd = 5
borders = partion.domain_builder1(A, Nd, inv = True)
print(borders)

print('--comparison--')
print('eq : {}'.format(partion.metrics2(
    partion.partion_equally(Nx, Nd), A)))
print('spec : {}'.format(partion.metrics2(
    borders, A)))

results['p2_m2_rc'] = np.copy(borders)
# Out:
# [   0  126  251  501  749 1000]
# --comparison--
# eq : 0.03576270787896105
# spec : 0.04311048309701605

# %%
Nd = 5
borders = partion.domain_builder2(A, Nd, inv = False, k = Nd+2)
print(borders)

print('--comparison--')
print('eq : {}'.format(partion.metrics1(
    partion.partion_equally(Nx, Nd), A)))
print('spec : {}'.format(partion.metrics1(
    borders, A)))

results['p1_m2_cl'] = np.copy(borders)
# Out:
# [   0  226  450  669  891 1000]
# --comparison--
# eq : 0.4199643135159226
# spec : 0.34142059952163106

# %%
Nd = 5
borders = partion.domain_builder2(A, Nd, inv = True, k = Nd+2)
print(borders)

print('--comparison--')
print('eq : {}'.format(partion.metrics2(
    partion.partion_equally(Nx, Nd), A)))
print('spec : {}'.format(partion.metrics2(
    borders, A)))

results['p2_m2_cl'] = np.copy(borders)
# Out:
# [   0  120  379  631  881 1000]
# --comparison--
# eq : 0.03576270787896105
# spec : 0.03618663168774449

# %%
borders = results['p1_m2_cl']

Nd = 5
param = {
    'Nx': Nx, 
    'Nt': Nt
}
bd1 = 0
bd2 = 1
nl_solver = aspen(Nd, borders, 1e-2, crit_abs = 1e-3)
solver_as = one_phase(param, D, nl_solver)
solver_as.x0 = np.copy(x0)
solver_as.setBoundary(bd1, bd2)
X, message, t = test(solver_as, x0, sample_size = 5)

results['t_m2'] = np.copy(t)
# Out:
# test started
# verdict : OK
# mean time : 48.11339883804321
# mean aspen iterations:  1.01

# %%
wrapper.show_res(solver_as)
wrapper.compare([solver_cl, solver_as], ['newton', 'aspen'])
# Out:
# iters : [6.17 1.01 1.   1.01 1.02]
# --time comparision--
# newton : 64.9014344215393
# aspen : 47.123106241226196

# %% [markdown]
# ##### Метод 3
# $$
# w(v, u) = \frac{|\frac{\partial (R(u)}{\partial u}|+ |\frac{\partial (R(v)}{\partial v}|}
# {|\frac{\partial (R(u)}{\partial v}|+|\frac{\partial (R(v)}{\partial u}|}
# $$

# %%
# Matrix of Weights
M = 5
A = np.zeros((Nx, Nx))
for i in range(M):
    step = Nt//M
    Jf = partion.precompute_Jf(solver_cl, X_cl[:, i*step], Nx)
    func = lambda i, j: m3(solver_cl, Jf, i, j)
    B = partion.adj_matrix(func, Nx)
    B /= np.max(B)
    A += B
A /= M
plt.matshow(A[650:750, 650:750])
plt.show()

# %%
Nd = 5
borders = partion.domain_builder1(A, Nd, inv = False)
print(borders)

print('--comparison--')
print('eq : {}'.format(partion.metrics1(
    partion.partion_equally(Nx, Nd), A)))
print('spec : {}'.format(partion.metrics1(
    borders, A)))

results['p1_m3_rc'] = np.copy(borders)
# Out:
# [   0  247  488  616  744 1000]
# --comparison--
# eq : 0.01603610093934795
# spec : 0.01912962444081176

# %%
Nd = 5
borders = partion.domain_builder1(A, Nd, inv = True)
print(borders)

print('--comparison--')
print('eq : {}'.format(partion.metrics2(
    partion.partion_equally(Nx, Nd), A)))
print('spec : {}'.format(partion.metrics2(
    borders, A)))

results['p2_m3_rc'] = np.copy(borders)
# Out:
# [   0  129  258  516  758 1000]
# --comparison--
# eq : 0.010048679474711594
# spec : 0.011833327678105788

# %%
Nd = 5
borders = partion.domain_builder2(A, Nd, inv = False, k = Nd+2)
print(borders)

print('--comparison--')
print('eq : {}'.format(partion.metrics1(
    partion.partion_equally(Nx, Nd), A)))
print('spec : {}'.format(partion.metrics1(
    borders, A)))

results['p1_m3_cl'] = np.copy(borders)
# Out:
# [   0  212  400  609  793 1000]
# --comparison--
# eq : 0.01603610093934795
# spec : 0.01624479046151061

# %%
Nd = 5
borders = partion.domain_builder2(A, Nd, inv = True, k = Nd+2)
print(borders)

print('--comparison--')
print('eq : {}'.format(partion.metrics2(
    partion.partion_equally(Nx, Nd), A)))
print('spec : {}'.format(partion.metrics2(
    borders, A)))

results['p2_m3_cl'] = np.copy(borders)
# Out:
# [   0  212  400  609  794 1000]
# --comparison--
# eq : 0.010048679474711594
# spec : 0.010164429231562817

# %%
borders = results['p2_m3_cl']

Nd = 5
param = {
    'Nx': Nx, 
    'Nt': Nt
}
bd1 = 0
bd2 = 1
nl_solver = aspen(Nd, borders, 1e-2, crit_abs = 1e-3)
solver_as = one_phase(param, D, nl_solver)
solver_as.x0 = np.copy(x0)
solver_as.setBoundary(bd1, bd2)
X, message, t = test(solver_as, x0, sample_size = 5)

results['t_m3'] = np.copy(t)
# Out:
# test started
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-636b97c806c6> in <module>
#      12 solver_as.x0 = np.copy(x0)
#      13 solver_as.setBoundary(bd1, bd2)
# ---> 14 X, message, t = test(solver_as, x0, sample_size = 5)
#      15
#      16 results['t_m3'] = np.copy(t)
#
# ~/Рабочий стол/aspen-study/notebooks/wrapper.py in wraper(*args, **kwargs)
#      18     def wraper(*args, **kwargs):
#      19         print('test started')
# ---> 20         solver, X, mes, t = obj(*args, **kwargs)
#      21         print('verdict : ' + mes)
#      22         print('mean time : {}'.format(t))
#
# ~/Рабочий стол/aspen-study/notebooks/wrapper.py in test(solver, x0, sample_size)
#      35         solver.init_log()
#      36         t -= time.time()
# ---> 37         X, mes = solver.solve()
#      38         t += time.time()
#      39     t /= sample_size
#
# ~/Рабочий стол/aspen-study/1D-difusion/one_phase.py in solve(self)
#     113                 self.solver.init_log()
#     114
# --> 115             X, mes = self.solver.solve(X)
#     116
#     117             if not(mes):
#
# ~/Рабочий стол/aspen-study/nonlin/aspen.py in solve(self, X)
#      57             # residual
#      58             t_res_gb = - time()
# ---> 59             R = self.f.val(X)
#      60             t_res_gb += time()
#      61             if(self.log_init):
#
# ~/Рабочий стол/aspen-study/1D-difusion/one_phase.py in val(self, X, st, end)
#     232
#     233             for i in range(st, end):
# --> 234                 self.Rx[i, :] = self.res_f(X, i)
#     235
#     236             return self.Rt[st:end]/self.dt + self.Rx[st:end] + self.outer.q[st:end]
#
# ~/Рабочий стол/aspen-study/1D-difusion/one_phase.py in <lambda>(X, i)
#     223             self.Rx = np.zeros((self.N, 1))
#     224
# --> 225             self.res_f = lambda X, i: outer_instance.FluxRes(X, i+1) - outer_instance.FluxRes(X, i)
#     226             self.jac_f = outer_instance.FluxJac
#     227
#
# ~/Рабочий стол/aspen-study/1D-difusion/one_phase.py in FluxRes(self, X, i)
#     156                 delta = np.array([X[i], X[i - 1]])
#     157             x = max(delta[0], delta[1])
# --> 158             mult = self.D.model(x)
#     159             val = - self.D.val[i]*self.param.Nx**2 * mult[0] * (delta[0] - delta[1])
#     160         else:
#
# <ipython-input-20-9ecd31c9b4fb> in model(u)
#       1 def model(u):
# ----> 2     return np.array([u**2+1, 2*max(u, 0)])
#       3
#       4 class Diffusion():
#       5     def __init__(self, Nx, Amp=0, Period=0, Scale=1, model=None):
#
# KeyboardInterrupt:

# %%
wrapper.show_res(solver_as)
wrapper.compare([solver_cl, solver_as], ['newton', 'aspen'])

# %%
print('---comparison---')
print('-eq-vs-m1-vs-m2-vs-m3-')
print('{:.4}'.format(t_eq),
     '{:.4}'.format(results['t_m1']),
     '{:.4}'.format(results['t_m2']),
     '{:.4}'.format(results['t_m3'])
     )

# %% [markdown]
# #### Вывод: лучшая метрика по критерию времени работы - m3

# %% [markdown]
# ##### Тест на рандомных границах

# %%
import csv
gather_data = True

Nd = 5
if gather_data:
    N = 150
    param = {
        'Nx': Nx, 
        'Nt': Nt
    }

    time = np.zeros(N)
    borders = np.zeros((Nd-1, N), dtype = 'int')
    num_of_alghs = 0

    for k in range(N):
        part = wrapper.generate_random(Nx, Nd)
        borders[:, k] = part[1:-1]
        nl_solver = aspen(Nd, part, 1e-2, crit_abs = 1e-3)
        solver_ts = one_phase(param, D, nl_solver)
        solver_ts.setBoundary(bd1, bd2)
        solver_ts.x0 = np.copy(x0)
        _, _, _, t = partion.test(solver_ts, x0, sample_size = 1)
        if(message != 'OK'):
            continue
        time[k] = t
        num_of_alghs += 1
        if k % 10 == 0:
            print(k)      
    # save data
    name = './data/Nx={},Nt={},Nd={}.csv'.format(Nx, Nt, Nd)
    filt = time > 0
    with open(name, 'a') as csvfile:
        writer = csv.writer(csvfile, delimiter=',')
        writer.writerows(borders[:, filt])
        writer.writerow(time[filt])
else:
    name = './data/Nx={},Nt={},Nd={}.csv'.format(Nx, Nt, Nd)
    with open(name, 'r') as csvfile:
        reader = csv.reader(csvfile)
        data = []
        for row in reader:
            data.append(row)        
        borders = np.array(data[0:Nd-1], dtype='int')
        time = np.array(data[Nd-1], dtype= 'float')
        num_of_alghs = np.sum(time > 0)

# %%
print('Numner og alghorithms that converged:', num_of_alghs)
print('mean time :', np.sum(time)/num_of_alghs)
sq_cov = np.sqrt(np.sum(time**2)/num_of_alghs-(np.sum(time)/num_of_alghs)**2)
print('sqrt cov :', np.sqrt(np.sum(time**2)/num_of_alghs-(np.sum(time)/num_of_alghs)**2))
# Out:
# Numner og alghorithms that converged: 124
# mean time : 73.19107317539954
# sqrt cov : 15.016313974396432

# %%
from scipy.stats import gaussian_kde
from scipy.integrate import quad

width = 4
win = np.arange(5, 155, width)
y = []
for x in win:
    mask = ((time < x+width/2) & (time > (x - width/2)))
    y.append(np.sum(mask)/ num_of_alghs/5)
    
plt.bar(win, y, width=width*0.5, color = 'r')
bw = 1/(1.06*sq_cov)*num_of_alghs**(1/5)
filt = time > 0
kernel = gaussian_kde(time[filt], bw_method=bw)

plt.axvline(t_new, label='newton', linestyle ='--', color='y')
plt.axvline(t_eq, label='eq', linestyle ='--', color='c')
plt.axvline(results['t_m1'], label='m1', linestyle ='--', color ='r')
plt.axvline(results['t_m2'], label='m2', linestyle ='--', color ='g')
plt.axvline(results['t_m3'], label='m3', linestyle ='--', color ='w')

plt.plot(np.linspace(0, 120, 100), kernel(np.linspace(0, 120, 100)))
#plt.xlim((0, 45))
plt.legend()
plt.show()

# %%
# we will estimate the efficency by function of distibution
p_eq, err_eq = quad(kernel, 0, t_eq)
print('equally partion : {}'.format(p_eq))
p_m1, err_m1 = quad(kernel, 0, results['t_m1'])
print('m1 partion : {}'.format(p_m1))
p_m2, err_m2 = quad(kernel, 0, results['t_m2'])
print('m2 partion : {}'.format(p_m2))
p_m3, err_m3 = quad(kernel, 0, results['t_m3'])
print('m3 partion : {}'.format(p_m3))
# Out:
# equally partion : 0.014391085908101127
# m1 partion : 0.034519656474436874
# m2 partion : 0.18904374731342619
# m3 partion : 0.07259268156435295

# %%
filt = time > 0
m1_list = []
m2_list = []
m3_list = []

# Matrix of Weights
# Matrix of Weights
M = 5
A1 = np.zeros((Nx, Nx))
A3 = np.zeros((Nx, Nx))
for i in range(M):
    step = Nt//M
    Jf = partion.precompute_Jf(solver_cl, X_cl[:, i*step], Nx)
    func = lambda i, j: m1(solver_cl, Jf, i, j)
    B = partion.adj_matrix(func, Nx)
    B /= np.max(B)
    A1 += B
    func = lambda i, j: m3(solver_cl, Jf, i, j)
    B = partion.adj_matrix(func, Nx)
    B /= np.max(B)
    A3 += B
A1 /= M
A3 /= M
func = lambda i, j: m2(solver_cl, X, i, j)
A2 = partion.adj_matrix(func, Nx)

func1 = lambda borders: metrics1(borders, A1)
func2 = lambda borders: metrics2(borders, A2)
func3 = lambda borders: metrics2(borders, A3)

for domain in borders[:, filt].T:
    part = np.concatenate(([0], domain, [Nx]), axis = 0)
    m1_list.append(func1(part))
    m2_list.append(func2(part))
    m3_list.append(func3(part))

m1_arr = np.array(m1_list)
m2_arr = np.array(m2_list)
m3_arr = np.array(m3_list)

plt.title('m1')
plt.scatter(m1_arr, time[filt])
plt.legend()
plt.xscale('log')
plt.savefig('m1', dpi = 120)
plt.show()
plt.title('m2')
plt.legend()
plt.scatter(m2_arr, time[filt])
plt.xscale('log')
plt.savefig('m2', dpi = 120)
plt.show()
plt.title('m3')
plt.legend()
plt.scatter(m3_arr, time[filt])
plt.xscale('log')
plt.savefig('m3', dpi = 120)
plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
print('--v---corr---v--')
cov_m1 = np.cov(np.stack((time[filt], m1_arr) , axis = 0))
print('m1 :', cov_m1[0, 1]/np.sqrt(cov_m1[1, 1])/np.sqrt(cov_m1[0, 0]))

cov_m2 = np.cov(np.stack((time[filt], m2_arr) , axis = 0))
print('m2 :', cov_m2[0, 1]/np.sqrt(cov_m2[1, 1])/np.sqrt(cov_m2[0, 0]))

cov_m3 = np.cov(np.stack((time[filt], m3_arr) , axis = 0))
print('m3 :', cov_m3[0, 1]/np.sqrt(cov_m3[1, 1])/np.sqrt(cov_m3[0, 0]))
# Out:
# --v---corr---v--
# m1 : 0.5075301216223223
# m2 : 0.3025603745581415
# m3 : 0.29785002035134883

# %%
plt.style.use('dark_background')
# inital condition
Nx = 1000
Nt = 100
D = Diffusion(Nx, 0.9, 1, 0.5e-1, model=model)
bd1 = 0
bd2 = 1
x = np.linspace(0, 1, Nx)
x0 = np.ones(Nx)
for k in range(1, 7):
    amp = np.random.random()
    x0 *= (1+amp*np.sin(k*np.pi*x))
x = np.linspace(bd1, bd2, Nx)
x0 *= x
x0 = np.reshape(x0, (-1, 1))
plt.xlabel('x0')
plt.ylabel('u')
plt.plot(x0)
plt.show()

# %%
param = {
    'Nx': Nx, 
    'Nt': Nt,
}
nl_solver = newton(1e-2, kmax = 14, crit_abs = 1e-3)
solver_cl = one_phase(param, D, nl_solver)
solver_cl.x0 = np.copy(x0)
solver_cl.setBoundary(bd1, bd2)
X_cl, message, t = test(solver_cl, x0, sample_size = 1)

wrapper.show_res(solver_cl)
# Out:
# test started
# verdict : OK
# mean time : 74.9912121295929
# mean newton iterations:  4.38

# %%
# Matrix of Weights
M = 5
A = np.zeros((Nx, Nx))
for i in range(M):
    step = Nt//M
    Jf = partion.precompute_Jf(solver_cl, X_cl[:, i*step], Nx)
    func = lambda i, j: m1(solver_cl, Jf, i, j)
    B = partion.adj_matrix(func, Nx)
    B /= np.max(B)
    A += B
A /= M
plt.matshow(A[150:250, 150:250])
plt.show()
print(A)
# Out:
# [[0.         0.11406401 0.         ... 0.         0.         0.        ]
#  [0.11406401 0.         0.11342562 ... 0.         0.         0.        ]
#  [0.         0.11342562 0.         ... 0.         0.         0.        ]
#  ...
#  [0.         0.         0.         ... 0.         0.05842205 0.        ]
#  [0.         0.         0.         ... 0.05842205 0.         0.05800732]
#  [0.         0.         0.         ... 0.         0.05800732 0.        ]]

# %%
Nd = 6
borders = partion.domain_builder2(A, Nd, inv = False, k = Nd+2)
print(borders)

print('--comparison--')
print('eq : {}'.format(partion.metrics1(
    partion.partion_equally(Nx, Nd), A)))
print('spec : {}'.format(partion.metrics1(
    borders, A)))

param = {
    'Nx': Nx, 
    'Nt': Nt
}
nl_solver = aspen(Nd, borders, 1e-2, crit_abs = 1e-3)
solver_as = one_phase(param, D, nl_solver)
solver_as.x0 = np.copy(x0)
solver_as.setBoundary(bd1, bd2)
X, message, t = test(solver_as, x0, sample_size = 1)
# Out:
# [   0  150  266  399  555  909 1000]
# --comparison--
# eq : 0.006174745857341645
# spec : 0.0025199721178584887
# test started
# verdict : OK
# mean time : 52.596014738082886
# mean aspen iterations:  1.15

# %%
wrapper.show_res(solver_as)
wrapper.compare([solver_cl, solver_as], ['newton', 'aspen'])
# Out:
# iters : [6.93 1.18 1.17 1.17 1.15 1.16]
# --time comparision--
# newton : 74.94237065315247
# aspen : 52.423378467559814

# %%
borders = partion.partion_equally(Nx, Nd)

param = {
    'Nx': Nx, 
    'Nt': Nt
}
nl_solver = aspen(Nd, borders, 1e-2, crit_abs = 1e-3)
solver_as = one_phase(param, D, nl_solver)
solver_as.x0 = np.copy(x0)
solver_as.setBoundary(bd1, bd2)
X, message, t = test(solver_as, x0, sample_size = 1)
# Out:
# test started
# verdict : OK
# mean time : 50.83537697792053
# mean aspen iterations:  1.14

# %%
wrapper.show_res(solver_as)
wrapper.compare([solver_cl, solver_as], ['newton', 'aspen'])
# Out:
# iters : [6.69 1.16 1.16 1.14 1.13 1.14]
# --time comparision--
# newton : 74.94237065315247
# aspen : 50.66879487037659
